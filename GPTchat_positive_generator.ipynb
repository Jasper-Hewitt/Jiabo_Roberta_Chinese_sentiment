# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasper-Hewitt/privatestuff/blob/main/GPTchat_positive_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.25.0.tar.gz (44 kB)
#      |████████████████████████████████| 44 kB 399 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pandas-stubs>=1.1.0.11
#   Downloading pandas_stubs-1.5.2.221213-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 33.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from openai) (1.21.6)
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.8/dist-packages (from openai) (1.3.5)
# Requirement already satisfied: openpyxl>=3.0.7 in /usr/local/lib/python3.8/dist-packages (from openai) (3.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai) (4.64.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.8/dist-packages (from openai) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from openai) (4.4.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl>=3.0.7->openai) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2.3->openai) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2.3->openai) (2.8.2)
# Collecting types-pytz>=2022.1.1
#   Downloading types_pytz-2022.6.0.1-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.3->openai) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2.10)
# Building wheels for collected packages: openai
#   Building wheel for openai (PEP 517) ... done
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=ed379a6e84e4627c8f002aaedfeffcd910fa54917d70e281d89e55f0f02712fc
#   Stored in directory: /root/.cache/pip/wheels/4b/92/33/6f57c7aae0b16875267999a50570e81f15eecec577ebe05a2e
# Successfully built openai
# Installing collected packages: types-pytz, pandas-stubs, openai
# Successfully installed openai-0.25.0 pandas-stubs-1.5.2.221213 types-pytz-2022.6.0.1

# %%
#get chatgpt to do some work, adjust prompts or number of requests in prompt if necessary.
#it will usually not give you more than 20 sentences per request, even though we ask it to give us a 100. 
import os
import openai
import json

openai.api_key = 'INSERT KEY' #remove key when uploading to github
bigstring = ''
m=0
while m<15:
  response = openai.Completion.create(
    model="text-davinci-003",
    prompt="請給我100個支持蔣萬安的句子",
    temperature=0.9,
    max_tokens=4050,
    top_p=1,
    frequency_penalty=0.0,
    presence_penalty=0.6,
    stop=[" Human:", " AI:"]
  )
  response
  json_object = json.loads(str(response))
  text = json_object['choices'][0]['text']
  bigstring = bigstring + text
  m=m+1

m=0
while m<15:
  response = openai.Completion.create(
    model="text-davinci-003",
    prompt="請給我100個佩服蔣萬安的句子",
    temperature=0.9,
    max_tokens=4050,
    top_p=1,
    frequency_penalty=0.0,
    presence_penalty=0.6,
    stop=[" Human:", " AI:"]
  )
  response
  json_object = json.loads(str(response))
  text = json_object['choices'][0]['text']
  bigstring = bigstring + text
  m=m+1

m=0
while m<15:
  response = openai.Completion.create(
    model="text-davinci-003",
    prompt="請給我100個稱讚某個政治人物的句子",
    temperature=0.9,
    max_tokens=4050,
    top_p=1,
    frequency_penalty=0.0,
    presence_penalty=0.6,
    stop=[" Human:", " AI:"]
  )
  response
  json_object = json.loads(str(response))
  text = json_object['choices'][0]['text']
  bigstring = bigstring + text
  m=m+1

m=0
while m<10:
  response = openai.Completion.create(
    model="text-davinci-003",
    prompt="請給我100個喜歡國民黨的句子",
    temperature=0.9,
    max_tokens=4050,
    top_p=1,
    frequency_penalty=0.0,
    presence_penalty=0.6,
    stop=[" Human:", " AI:"]
  )
  response
  json_object = json.loads(str(response))
  text = json_object['choices'][0]['text']
  bigstring = bigstring + text
  m=m+1

len(bigstring)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-86-00515497d22f> in <module>
#       8 m=0
#       9 while m<20:
# ---> 10   response = openai.Completion.create(
#      11     model="text-davinci-003",
#      12     prompt="請給我100個支持蔣萬安的句子",
#
# /usr/local/lib/python3.8/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.8/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     113         )
#     114         url = cls.class_url(engine, api_type, api_version)
# --> 115         response, _, api_key = requestor.request(
#     116             "post",
#     117             url,
#
# /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     179             request_timeout=request_timeout,
#     180         )
# --> 181         resp, got_stream = self._interpret_response(result, stream)
#     182         return resp, got_stream, self.api_key
#     183
#
# /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     394         else:
#     395             return (
# --> 396                 self._interpret_response_line(
#     397                     result.content, result.status_code, result.headers, stream=False
#     398                 ),
#
# /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427         stream_error = stream and "error" in resp.data
#     428         if stream_error or not 200 <= rcode < 300:
# --> 429             raise self.handle_error_response(
#     430                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431             )
#
# RateLimitError: You exceeded your current quota, please check your plan and billing details.

# %%
bigstring = bigstring.split('.')

# %%
#create a corresponding index for the sentences.
indoix = []
for i in range(len(bigstring)):
  indoix.append(i)

# %%
#put both lists together in a dictionary
d = {'Indoix':indoix,'Text':bigstring}

# %%
#put into dataframe and drop 'indoix' column. 
import pandas as pd
df = pd.DataFrame(d)
df = df['Text']
df = df.to_frame()

# %%
df
# Out:
#                                        Text
# 0                                     \n\n1
# 1                  我堅信蔣萬安能為台灣人帶來更多繁榮與平安。\n2
# 2                       蔣萬安的領導才是台灣最好的希望！\n3
# 3                 我們要支持蔣萬安，讓他為台灣的未來出一分力！\n4
# 4             我支持蔣萬安，相信他可以全心全意為台灣帶來好的未來！\n5
# ..                                      ...
# 116     蔣萬安清楚瞭解台灣面對的種種挑戰，能夠提出有效而可行的解決方案。\n7
# 117        蔣萬安懷抱優雅而深植於土地之中的台灣文化，為本土力量發聲。\n8
# 118     蔣萬安認為台灣該有的是一個友好的政策環境，來提升地區的經濟發展。\n9
# 119     支持蔣萬安的公民智慧，務求建立台灣平等，開放，和平的政治環境。\n10
# 120   鼓勵蔣萬安以推行台灣的共同理想，為建立新的政策、技術、法律和制度作出努力。
#
# [121 rows x 1 columns]

# %%
#get rid of all the \n2 \n3
df = df[df['Text'].str.len()>4]
df = df.reset_index()
df=df['Text'].to_frame()
df
# Out:
#                                        Text
# 0                  我堅信蔣萬安能為台灣人帶來更多繁榮與平安。\n2
# 1                       蔣萬安的領導才是台灣最好的希望！\n3
# 2                 我們要支持蔣萬安，讓他為台灣的未來出一分力！\n4
# 3             我支持蔣萬安，相信他可以全心全意為台灣帶來好的未來！\n5
# 4                    我們正在看見蔣萬安正在改變台灣，加油！\n6
# ..                                      ...
# 115     蔣萬安清楚瞭解台灣面對的種種挑戰，能夠提出有效而可行的解決方案。\n7
# 116        蔣萬安懷抱優雅而深植於土地之中的台灣文化，為本土力量發聲。\n8
# 117     蔣萬安認為台灣該有的是一個友好的政策環境，來提升地區的經濟發展。\n9
# 118     支持蔣萬安的公民智慧，務求建立台灣平等，開放，和平的政治環境。\n10
# 119   鼓勵蔣萬安以推行台灣的共同理想，為建立新的政策、技術、法律和制度作出努力。
#
# [120 rows x 1 columns]

# %%
#get rid of more trash
import re
newline_symbols='/\r?\n|\r/'
numbers='[0-9]'
df['Text'] = df['Text'].replace(newline_symbols,'',regex=True)
df['Text'] = df['Text'].replace(numbers,'',regex=True)

# %%
df
# Out:
#                                        Text
# 0                   我堅信蔣萬安能為台灣人帶來更多繁榮與平安。\n
# 1                        蔣萬安的領導才是台灣最好的希望！\n
# 2                  我們要支持蔣萬安，讓他為台灣的未來出一分力！\n
# 3              我支持蔣萬安，相信他可以全心全意為台灣帶來好的未來！\n
# 4                     我們正在看見蔣萬安正在改變台灣，加油！\n
# ..                                      ...
# 115      蔣萬安清楚瞭解台灣面對的種種挑戰，能夠提出有效而可行的解決方案。\n
# 116         蔣萬安懷抱優雅而深植於土地之中的台灣文化，為本土力量發聲。\n
# 117      蔣萬安認為台灣該有的是一個友好的政策環境，來提升地區的經濟發展。\n
# 118       支持蔣萬安的公民智慧，務求建立台灣平等，開放，和平的政治環境。\n
# 119   鼓勵蔣萬安以推行台灣的共同理想，為建立新的政策、技術、法律和制度作出努力。
#
# [120 rows x 1 columns]

# %%
df.to_excel("Chiang_positive_train_data.xlsx")
