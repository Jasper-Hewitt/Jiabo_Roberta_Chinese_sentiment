# %%
import pandas as pd
df = pd.read_excel('/content/Chiang_predicted_time.xlsx')

# %%
df
# Out:
#       Unnamed: 0                                               text  pred  \
# 0              0  台灣推新聞\n\n·\n爆料北市府多人留任蔣萬安小內閣 柯大笑：代表我的局處長太優秀 - 自...     1
# 1              1                              \n\n·\n蔣萬安聽清楚了！\n:\n      1
# 2              2  鉅石會\n\n·\n中共對台文攻武嚇，近年變本加厲備受國際關注，台灣人抗中保台是天經地義。\...     1
# 3              3  吳奕軍 \n\n·\n中共對台文攻武嚇，近年變本加厲備受國際關注，台灣人抗中保台是天經地義。...     1
# 4              4  台灣大叔\n\n·\n  \n\n要檢討個人，趁現在還可以自由說話，快點大力檢討。\n以後共...     0
# ...          ...                                                ...   ...
# 1471        1471  台灣推新聞\n\n·\n 藍質疑曾赴中國醫學交流 陳時中競辦：轉移蔣萬安矽谷經驗焦點 - 自...     0
# 1472        1472  李俊賢\n\n·\n   \n\n: 辭立委喊喊而已？蔣萬安拖天才完成辭職手續 楞好幾拍效率...     0
# 1473        1473   \n\n·\n 高虹安李忠庭列被告！高虹安票太多嘲諷馬英九死亡之握？！台積電大舉投資棄台論...     0
# 1474        1474  三立\n\n·\n 辭立委喊喊而已？蔣萬安拖天才完成辭職手續 楞好幾拍效率也太差！吹噓矽谷經...     0
# 1475        1475  \n\n·\n 這是必須面對的現實\n\n我們公司的三代（注意是三代）\n\n也被我問到承認...     0
#
#                      timestamp
# 0     2022-12-10T03:09:52.000Z
# ...

# %%
# Convert the 'date' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d')

# Convert the datetime objects to normal date strings
df['timestamp'] = df['timestamp'].dt.strftime('%Y-%m-%d')

# Group the data by date and sentiment
grouped = df.groupby(['timestamp', 'pred'])

# Count the number of rows in each group
counts = grouped.size().reset_index(name='count')

# Print the resulting dataframe
#print(counts)

# Pivot the data so that each date has a separate row
pivoted = counts.pivot_table(index='timestamp', columns='pred', values='count', fill_value=0)

# Print the resulting dataframe
#pivoted
pivoted.plot(kind='bar', stacked=True)

# %%
df
# Out:
#       Unnamed: 0                                               text  pred  \
# 0              0  台灣推新聞\n\n·\n爆料北市府多人留任蔣萬安小內閣 柯大笑：代表我的局處長太優秀 - 自...     1
# 1              1                              \n\n·\n蔣萬安聽清楚了！\n:\n      1
# 2              2  鉅石會\n\n·\n中共對台文攻武嚇，近年變本加厲備受國際關注，台灣人抗中保台是天經地義。\...     1
# 3              3  吳奕軍 \n\n·\n中共對台文攻武嚇，近年變本加厲備受國際關注，台灣人抗中保台是天經地義。...     1
# 4              4  台灣大叔\n\n·\n  \n\n要檢討個人，趁現在還可以自由說話，快點大力檢討。\n以後共...     0
# ...          ...                                                ...   ...
# 1471        1471  台灣推新聞\n\n·\n 藍質疑曾赴中國醫學交流 陳時中競辦：轉移蔣萬安矽谷經驗焦點 - 自...     0
# 1472        1472  李俊賢\n\n·\n   \n\n: 辭立委喊喊而已？蔣萬安拖天才完成辭職手續 楞好幾拍效率...     0
# 1473        1473   \n\n·\n 高虹安李忠庭列被告！高虹安票太多嘲諷馬英九死亡之握？！台積電大舉投資棄台論...     0
# 1474        1474  三立\n\n·\n 辭立委喊喊而已？蔣萬安拖天才完成辭職手續 楞好幾拍效率也太差！吹噓矽谷經...     0
# 1475        1475  \n\n·\n 這是必須面對的現實\n\n我們公司的三代（注意是三代）\n\n也被我問到承認...     0
#
#        timestamp
# 0     2022-12-10
# 1     2022-12-10
# 2     2022-12-10
# ...

# %%
# Group the data by date and sentiment
grouped = df.groupby(['timestamp', 'pred'])

# Count the number of rows in each group
counts = grouped.size().reset_index(name='count')

# Print the resulting dataframe
print(counts)
# Out:
#      timestamp  pred  count
# 0   2022-11-18     0     33
# 1   2022-11-18     1      3
# 2   2022-11-19     0     20
# 3   2022-11-19     1      8
# 4   2022-11-20     0     35
# 5   2022-11-20     1     10
# 6   2022-11-21     0     20
# 7   2022-11-21     1     15
# 8   2022-11-22     0     16
# 9   2022-11-22     1     13
# 10  2022-11-23     0     19
# 11  2022-11-23     1     13
# 12  2022-11-24     0     20
# 13  2022-11-24     1     24
# 14  2022-11-25     0     46
# 15  2022-11-25     1     44
# 16  2022-11-26     0    239
# 17  2022-11-26     1    147
# 18  2022-11-27     0    113
# 19  2022-11-27     1     80
# 20  2022-11-28     0     78
# 21  2022-11-28     1     28
# 22  2022-11-29     0     72
# 23  2022-11-29     1     35
# 24  2022-11-30     0     51
# 25  2022-11-30     1     31
# 26  2022-12-01     0     29
# 27  2022-12-01     1     24
# 28  2022-12-02     0     25
# 29  2022-12-02     1     24
# 30  2022-12-03     0     17
# 31  2022-12-03     1     15
# ...

# %%
# Pivot the data so that each date has a separate row
pivoted = counts.pivot_table(index='timestamp', columns='pred', values='count', fill_value=0)

# Print the resulting dataframe
pivoted
# Out:
# pred          0    1
# timestamp
# 2022-11-18   33    3
# 2022-11-19   20    8
# 2022-11-20   35   10
# 2022-11-21   20   15
# 2022-11-22   16   13
# 2022-11-23   19   13
# 2022-11-24   20   24
# 2022-11-25   46   44
# 2022-11-26  239  147
# 2022-11-27  113   80
# 2022-11-28   78   28
# 2022-11-29   72   35
# 2022-11-30   51   31
# 2022-12-01   29   24
# 2022-12-02   25   24
# 2022-12-03   17   15
# 2022-12-04    9    2
# 2022-12-05   26   13
# 2022-12-06   13    9
# 2022-12-07   13    9
# 2022-12-08   11    4
# 2022-12-09    9    7
# 2022-12-10    0    4

# %%
# Plot the stacked bar chart
#plt.pivoted(figsize=(20, 20))
pivoted.plot(kind='bar', stacked=True)

# %%
cumulative = pivoted.cumsum()

# %%
cumulative
# Out:
# pred          0    1
# timestamp
# 2022-11-18   33    3
# 2022-11-19   53   11
# 2022-11-20   88   21
# 2022-11-21  108   36
# 2022-11-22  124   49
# 2022-11-23  143   62
# 2022-11-24  163   86
# 2022-11-25  209  130
# 2022-11-26  448  277
# 2022-11-27  561  357
# 2022-11-28  639  385
# 2022-11-29  711  420
# 2022-11-30  762  451
# 2022-12-01  791  475
# 2022-12-02  816  499
# 2022-12-03  833  514
# 2022-12-04  842  516
# 2022-12-05  868  529
# 2022-12-06  881  538
# 2022-12-07  894  547
# 2022-12-08  905  551
# 2022-12-09  914  558
# 2022-12-10  914  562

# %%
import matplotlib.pyplot as plt

# Plot the sentiment over time
cumulative.plot(kind='line')

# Show the plot
plt.show()

# %%
import datetime

# The date string with the weird pattern
date_string = "2022-12-10T03:09:52.000Z"

# Parse the date string using the datetime module
date = datetime.datetime.strptime(date_string, "%d/%m/%y")

# Convert the date to the normal format using the strftime method
normal_date = date.strftime("%Y-%m-%d")

# Print the result
print(normal_date)  # Output: "2021-02-01 15:30:00"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6a60187ab812> in <module>
#       5
#       6 # Parse the date string using the datetime module
# ----> 7 date = datetime.datetime.strptime(date_string, "%d/%m/%y")
#       8
#       9 # Convert the date to the normal format using the strftime method
#
# /usr/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# ...

# %%
positive=testing_pd.loc[testing_pd['pred']==1] 
negative=testing_pd.loc[testing_pd['pred']==0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4d2e72092653> in <module>
# ----> 1 positive=testing_pd.count[testing_pd['pred']==1]
#       2 negative=testing_pd.loc[testing_pd['pred']==0]
#
# TypeError: 'method' object is not subscriptable

# %%
pos_posts=positive.count()

# %%
# Out:
# Unnamed: 0    562
# text          562
# pred          562
# timestamp     562
# dtype: int64

# %%
negative.count()
# Out:
# Unnamed: 0    914
# text          914
# pred          914
# timestamp     914
# dtype: int64

# %%
year = pivoted['timestamp']
population_by_continent = {
    'positive': pivoted.loc[pivoted['1']],
    'negative': pivoted.loc[pivoted['1']]

}

fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys(), alpha=0.8)
ax.legend(loc='upper left')
ax.set_title('World population')
ax.set_xlabel('Year')
ax.set_ylabel('Number of people (millions)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-e1466515b98d> in <module>
# ----> 1 year = pivoted['timestamp']
#       2 population_by_continent = {
# ...
