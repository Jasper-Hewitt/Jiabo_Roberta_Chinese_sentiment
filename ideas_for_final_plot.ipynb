# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasper-Hewitt/privatestuff/blob/main/ideas_for_final_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#I can put the variables for the positive/negative counts in this dataframe
import pandas as pd
data = {
  "candidate": ['Chen-Shitsung', 'Huang-shanshan', 'Chiang-Wanan'],
  "positive": [300, 500, 600],
  "negative": [1000, 1000, 1000]
}
df1 = pd.DataFrame(data)
df1
# Out:
#         candidate  positive  negative
# 0   Chen-Shitsung       300      1000
# 1  Huang-shanshan       500      1000
# 2    Chiang-Wanan       600      1000

# %%
#Perhaps try to get these amounts in percentage. I will have to change that in the dataframe, so lemme see for a bit how that would work 
import matplotlib.pyplot as plt
df1.plot.bar(x='candidate')
plt.title("sentiment on Twitter")
plt.show()

# %%
# yeah I can make it like this, and try to store the percentage thingies in here instead
chen_count_pos=300
chen_count_neg=1000

Shan_count_pos=100 
shan_count_neg=1000

Chiang_count_pos=98
Chiang_count_neg=1000

import pandas as pd
data = {
  "candidate": ['Chen-Shitsung', 'Huang-shanshan', 'Chiang-Wanan'],
  "positive": [chen_count_pos, Shan_count_pos, Chiang_count_pos],
  "negative": [chen_count_neg, shan_count_neg, Chiang_count_neg]
}
df2 = pd.DataFrame(data)
df2
# Out:
#         candidate  positive  negative
# 0   Chen-Shitsung       300      1000
# 1  Huang-shanshan       100      1000
# 2    Chiang-Wanan        98      1000
